# %% [markdown]
# <a href="https://colab.research.google.com/github/bagas32/latihan/blob/main/mini_project_analyst_data_sales_ecommerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mini project: Analisis Data Penjualan E-commerce 🛒**
#
# Alurnya:
#
# 1. Bikin DataFrame dari data dummy (misalnya: order_id, customer, product, quantity, price).
#
# 2. Hitung total harga per transaksi (quantity × price).
#
# 3. Tambah kolom kategori produk (misalnya: elektronik, fashion, food).
#
# 4. Filter transaksi dengan nilai di atas Rp500.000.
#
# 5. GroupBy kategori produk → hitung total penjualan per kategori.
#
# 6. (Optional) Merge dengan DataFrame lain, misalnya data customer (nama, kota), biar lebih kaya datanya.
#
# **Output akhirnya bisa kayak laporan mini:**
#
# a. Top 3 customer dengan belanja terbesar.
#
# b. Penjualan per kategori.
#
# c. Rata-rata order value.

# %%
#1
import pandas as pd

data = {
    "order_id": [101, 102, 103, 104, 105],
    "customer": ["Andi", "Budi", "Citra", "Dewi", "Eka"],
    "customer_id": ["c005", "c010", "c058", "c502", "c505"],
    "product": ["minyak", "telur", "iphone", "sunscreen", "stratocaster"],
    "quantity": [7, 5, 1, 2, 1],
    "price": [70000, 10000, 6000000, 65000, 5500000]
}

data_penjualan = pd.DataFrame(data)
print(data_penjualan)
# Out:
#    order_id customer customer_id       product  quantity    price
# 0       101     Andi        c005        minyak         7    70000
# 1       102     Budi        c010         telur         5    10000
# 2       103    Citra        c058        iphone         1  6000000
# 3       104     Dewi        c502     sunscreen         2    65000
# 4       105      Eka        c505  stratocaster         1  5500000

# %%
#2
data_penjualan['total_price'] = data_penjualan['quantity'] * data_penjualan['price']
display(data_penjualan)
# Out:
#    order_id customer customer_id       product  quantity    price  total_price
# 0       101     Andi        c005        minyak         7    70000       490000
# 1       102     Budi        c010         telur         5    10000        50000
# 2       103    Citra        c058        iphone         1  6000000      6000000
# 3       104     Dewi        c502     sunscreen         2    65000       130000
# 4       105      Eka        c505  stratocaster         1  5500000      5500000

# %%
#3
data_penjualan['category'] = ['makanan', 'makanan', 'elektronik', 'kesehatan', 'elektronik']

new_column_order = ['order_id', 'customer', 'customer_id', 'product', 'category', 'quantity', 'price', 'total_price']

data_penjualan = data_penjualan[new_column_order]
display(data_penjualan)
# Out:
#    order_id customer customer_id       product    category  quantity    price  \
# 0       101     Andi        c005        minyak     makanan         7    70000
# 1       102     Budi        c010         telur     makanan         5    10000
# 2       103    Citra        c058        iphone  elektronik         1  6000000
# 3       104     Dewi        c502     sunscreen   kesehatan         2    65000
# 4       105      Eka        c505  stratocaster  elektronik         1  5500000
#
#    total_price
# 0       490000
# 1        50000
# 2      6000000
# 3       130000
# 4      5500000

# %%
#4
filter_transaction = data_penjualan[data_penjualan['total_price'] > 500000]
display(filter_transaction)
# Out:
#    order_id customer customer_id       product    category  quantity    price  \
# 2       103    Citra        c058        iphone  elektronik         1  6000000
# 4       105      Eka        c505  stratocaster  elektronik         1  5500000
#
#    total_price
# 2      6000000
# 4      5500000

# %%
#5
group_category = data_penjualan.groupby('category')['total_price'].sum()
display(group_category)
# Out:
# category
# elektronik    11500000
# kesehatan       130000
# makanan         540000
# Name: total_price, dtype: int64

# %%
#6
data_customer = {
    "customer_id": ["c005", "c010", "c058", "c502", "c505"],
    "customer": ["Andi", "Budi", "Citra", "Dewi", "Eka"],
    "city": ["jambi", "jakarta", "jakarta", "surabaya", "bogor"],
    "city_id": ["ct09", "ct01", "ct01", "ct10", "ct03"]
}

dt_customer = pd.DataFrame(data_customer)
print(dt_customer)
# Out:
#   customer_id customer      city city_id
# 0        c005     Andi     jambi    ct09
# 1        c010     Budi   jakarta    ct01
# 2        c058    Citra   jakarta    ct01
# 3        c502     Dewi  surabaya    ct10
# 4        c505      Eka     bogor    ct03

# %%
#6
merged_dt = pd.merge(data_penjualan.drop(columns=["customer"]), dt_customer, on="customer_id", how="inner")

merged_dt = merged_dt[
    ["order_id", "customer", "customer_id", "city", "city_id",
     "product", "category", "quantity", "price", "total_price"]]

display(merged_dt)
# Out:
#    order_id customer customer_id      city city_id       product    category  \
# 0       101     Andi        c005     jambi    ct09        minyak     makanan
# 1       102     Budi        c010   jakarta    ct01         telur     makanan
# 2       103    Citra        c058   jakarta    ct01        iphone  elektronik
# 3       104     Dewi        c502  surabaya    ct10     sunscreen   kesehatan
# 4       105      Eka        c505     bogor    ct03  stratocaster  elektronik
#
#    quantity    price  total_price
# 0         7    70000       490000
# 1         5    10000        50000
# 2         1  6000000      6000000
# 3         2    65000       130000
# 4         1  5500000      5500000

# %% [markdown]
# # **Laporan mini project:**

# %% [markdown]
# ## Top 3 sales

# %%
#a
top_3_sales = merged_dt.sort_values(by='total_price', ascending=False).head(3)
display(top_3_sales)
# Out:
#    order_id customer customer_id     city city_id       product    category  \
# 2       103    Citra        c058  jakarta    ct01        iphone  elektronik
# 4       105      Eka        c505    bogor    ct03  stratocaster  elektronik
# 0       101     Andi        c005    jambi    ct09        minyak     makanan
#
#    quantity    price  total_price
# 2         1  6000000      6000000
# 4         1  5500000      5500000
# 0         7    70000       490000

# %% [markdown]
# ## Top sales per category

# %%
#b
top_sales_per_category = merged_dt.groupby('category')['total_price'].sum().sort_values(ascending=False)
display(top_sales_per_category)
# Out:
# category
# elektronik    11500000
# makanan         540000
# kesehatan       130000
# Name: total_price, dtype: int64

# %% [markdown]
# ## Average order value

# %%
#c
average_order_value = merged_dt['total_price'].mean()
print(f"average order value: {average_order_value}")
# Out:
# average order value: 2434000.0

# %% [markdown]
# done
# from 1.09 am
# to 2.26 am
#
# 8/30/2025
